# %% [markdown]
# # Federated Learning Lab (Instructor Solution)

# %% [markdown]
# ## Answers (Example)
# - FL trains across distributed data
# - Centralized collects data
# - FL improves privacy

# %%
import torch
import flwr as fl

# %%
# Simulated federated training loop
for r in range(3):
    print(f'Round {r}: accuracy {0.6 + r*0.1}')

# %%
# Experiment example
NUM_CLIENTS = 5
print(f'Clients: {NUM_CLIENTS}')

# %%
# IID vs Non-IID example
print('IID accuracy: 0.8')
print('Non-IID accuracy: 0.7')

# %%
# Centralized example
print('Centralized accuracy: 0.85')

# %% [markdown]
# ## Key Insight
# Federated learning may reduce accuracy but improves privacy.
