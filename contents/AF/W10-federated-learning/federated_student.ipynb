# %% [markdown]
# # Federated Learning Lab (Student Version)
#
# Fill in the TODO sections and answer the questions.

# %% [markdown]
# ## Part 1: Concept Questions
#
# Answer briefly:
# 1. What is federated learning?
# 2. Difference with centralized learning?
# 3. Why is it useful for privacy?

# %%
# TODO: Run this cell to import libraries
import torch
import flwr as fl
print('Libraries loaded')

# %% [markdown]
# ## Part 2: Run Federated Learning
# Observe the output.

# %%
# TODO: Run federated training (predefined)
print('Simulated federated training...')

# %% [markdown]
# Questions:
# - Does accuracy improve?
# - Why multiple clients?

# %% [markdown]
# ## Part 3: Experiment
# Change ONE parameter below

# %%
# TODO: Modify parameter
NUM_CLIENTS = 2  # change this
print(f'Clients: {NUM_CLIENTS}')

# %% [markdown]
# Questions:
# - What changed?
# - Faster/slower?
# - Accuracy?

# %% [markdown]
# ## Part 4: IID vs Non-IID

# %%
# TODO: Compare two distributions
print('Running IID...')
print('Running Non-IID...')

# %% [markdown]
# Questions:
# - Which is better?
# - Why?

# %% [markdown]
# ## Part 5: Centralized Model

# %%
# TODO: Run centralized training
print('Centralized training...')

# %% [markdown]
# Final Reflection:
# - What did you learn?
# - What surprised you?
